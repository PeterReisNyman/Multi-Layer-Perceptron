# %% [markdown]
# # Assignment 4 (Multi-Layer Perceptron)

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn import preprocessing
from imblearn.over_sampling import RandomOverSampler
import pandas as pd
import  numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from sklearn.model_selection import GridSearchCV

ds = sklearn.datasets.load_wine(return_X_y=False, as_frame=False)
ix = [i for i,d in enumerate(ds['feature_names']) if d =='od280/od315_of_diluted_wines']
ds['feature_names'][ix[0]] = 'ratio_of_diluted_wines'

X = ds['data']
Y = ds['target']
ros = RandomOverSampler(random_state=42)
X_ros, Y_ros = ros.fit_resample(X, Y)
standardized_X = preprocessing.scale(X)
standardized_X_ros = preprocessing.scale(X_ros)

plt.rcParams.update({
    "xtick.labelsize": 6,
    "ytick.labelsize": 6
})

# %%
# 1 Base line model

# %%
# 1.1 Build an MLP classifier using the standard setup from SK-learn and evaluate its performance with regard to the performance
# measures that we have used during the lectures.

# %%
x_tr, x_te, y_tr, y_te = train_test_split( X, Y, test_size = 0.2)
model_default = MLPClassifier(max_iter = 10000)
model_default.fit(x_tr, y_tr)
print(f"\nThis model has {model_default.n_layers_} layers\n")
print(f"This model has {model_default.hidden_layer_sizes} neurons in its hiden layer\n")
scores_default = cross_val_score(model_default, X, Y, cv = 10, scoring = 'accuracy')
print(f"{scores_default} \n")
print(f"{scores_default.mean()} \n")
predictions_default = model_default.predict(x_te)

print(classification_report(y_te, predictions_default))
# Out:
# This model has 3 layers
#
# This model has (100,) neurons in its hiden layer
#
# [0.33333333 0.27777778 0.5        0.44444444 0.83333333 0.55555556
#  1.         0.33333333 0.35294118 1.        ]
#
# 0.5630718954248366
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93        15
#            1       0.85      0.85      0.85        13
#            2       0.80      1.00      0.89         8
#
#     accuracy                           0.89        36
#    macro avg       0.88      0.90      0.89        36
# weighted avg       0.90      0.89      0.89        36

# %%
pd.crosstab(y_te, predictions_default)
# Out:
# col_0   0   1  2
# row_0
# 0      13   2  0
# 1       0  11  2
# 2       0   0  8

# %%
# 1.2 Build an MLP classifier in accordance with the rules of thumb and your knowledge about the dataset (complexity, balance, etc.)

# %%
# 1.2.1 Motivate how you used the rules of thumb and your EDA knowledge to establish your MLP setup

# %% [markdown]
# We apply the rules of thumb by: 1. Determining number of input and output neurons: We have 13 input neurons, the 13 features of the wine and we have 3 output neurons, the three classes of the wine. So The hidden layer size should be between 3 and 13. 2. Calculate with the mean the input and output neurons and divide them by two. 3. The number of hidden neurons should be less than twice the size of the input layer. 4. The 2/3 the size of the input layer, plus the size of the output layer.
#
# 1.   → 1-13 hidden neurons
# 2.   (3 + 13) / 2 = 8 → 8 hidden neurons
# 3.   23 < 2*13 → 1-25 hidden neurons
# 4.   (3*(2/3))+13 → 15 hidden neurons
#
# Applying the rules of thumb gives us a result of 15 hidden neurons.

# %%
# 1.2.2 Build the model and evaluate it through the set of performance measures

# %%
x_tr, x_te, y_tr, y_te = train_test_split( X, Y, test_size = 0.2)
model_HL = MLPClassifier(hidden_layer_sizes = (15), max_iter = 10000)
model_HL.fit(x_tr, y_tr)
print(f"This model has {model_HL.n_layers_} layers\n")
print(f"This model has {model_HL.hidden_layer_sizes} neurons\n")
scores_HL = cross_val_score(model_default, X, Y, cv = 10, scoring = 'accuracy')
print(f"{scores_HL} \n")
print(f"{scores_HL.mean()} \n")

predictions_HL = model_HL.predict(x_te)

print(classification_report(y_te, predictions_HL))
# Out:
# This model has 3 layers
#
# This model has 15 neurons
#
# [0.5        0.94444444 0.61111111 0.44444444 0.83333333 0.33333333
#  0.44444444 1.         0.52941176 1.        ]
#
# 0.6640522875816993
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         9
#            1       0.00      0.00      0.00        17
#            2       0.28      1.00      0.43        10
#
#     accuracy                           0.28        36
#    macro avg       0.09      0.33      0.14        36
# weighted avg       0.08      0.28      0.12        36
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
pd.crosstab(y_te, predictions_HL)
# Out:
# col_0   2
# row_0
# 0       9
# 1      17
# 2      10

# %%
# 3. Choose the best base line model out of the two above. Motivate why you deem this model setup to be better.

# %% [markdown]
# Our second model with our specified 15 neurons in the hidden layer achieves a bit lower accuracy vs the default model with 100 neurons in the hidden layer. Given that we applied the rules of thumb, it should in theory provide better a better result, however, as the accuracy results speak against it, we chose the default model as the better. The boxpolt below shows this in detail.

# %%
results = {}

our = []
default = []
for _ in range(200):
    x_tr, x_te, y_tr, y_te = train_test_split(X,Y,  test_size=0.2)

    m = MLPClassifier(hidden_layer_sizes=(15,), max_iter=10000)
    m.fit(x_tr, y_tr)

    model_default = MLPClassifier(max_iter = 10000)
    model_default.fit(x_tr, y_tr)

    default.append(accuracy_score(y_te, model_default.predict(x_te)))
    our.append(accuracy_score(y_te, m.predict(x_te)))

results['our'] = our
results['default'] = default

plt.boxplot(results.values(), labels=results.keys())
plt.xlabel('Hidden layer size')
plt.ylabel('Accuracy')
plt.show()
# Out:
# /var/folders/y0/dl2c3bsn41b0y9ffbsz7z3th0000gn/T/ipykernel_14212/1089455822.py:20: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(results.values(), labels=results.keys())

# %%
# 1. You can use all the data preparation techniques that you have learned during the course. Motivate what steps you choose and why and the possible positive and negative consequences of those steps.

# %%
x_tr, x_te, y_tr, y_te = train_test_split(standardized_X,Y, test_size=0.2)
model_default = MLPClassifier(max_iter = 10000)
model_default.fit(x_tr, y_tr)
print(f"\nThis model has {model_default.n_layers_} layers\n")
print(f"This model has {model_default.hidden_layer_sizes} neurons\n")
scores_default = cross_val_score(model_default, standardized_X,Y, cv = 10, scoring = 'accuracy')
print(f"{scores_default} \n")
print(f"{scores_default.mean()} \n")
predictions_default = model_default.predict(x_te)

print(classification_report(y_te, predictions_default))
# Out:
# This model has 3 layers
#
# This model has (100,) neurons
#
# [0.94444444 0.94444444 0.94444444 0.94444444 0.94444444 0.94444444
#  1.         1.         0.94117647 1.        ]
#
# 0.9607843137254901
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00         9
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
pd.crosstab(y_te, predictions_default)
# Out:
# col_0   0   1  2
# row_0
# 0      13   0  0
# 1       0  14  0
# 2       0   0  9

# %%
model_HL = MLPClassifier(hidden_layer_sizes = (15), max_iter = 1000)
model_HL.fit(x_tr, y_tr)
print(f"This model has {model_HL.n_layers_} layers\n")
print(f"This model has {model_HL.hidden_layer_sizes} neurons\n")
scores_HL = cross_val_score(model_default, standardized_X,Y, cv = 10, scoring = 'accuracy')
print(f"{scores_HL} \n")
print(f"{scores_HL.mean()} \n")

predictions_HL = model_HL.predict(x_te)

print(classification_report(y_te, predictions_HL))
# Out:
# This model has 3 layers
#
# This model has 15 neurons
#
# [1.         1.         0.94444444 0.94444444 1.         1.
#  1.         1.         1.         1.        ]
#
# 0.9888888888888889
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.93      1.00      0.97        14
#            2       1.00      0.89      0.94         9
#
#     accuracy                           0.97        36
#    macro avg       0.98      0.96      0.97        36
# weighted avg       0.97      0.97      0.97        36

# %%
pd.crosstab(y_te, predictions_HL)
# Out:
# col_0   0   1  2
# row_0
# 0      13   0  0
# 1       0  14  0
# 2       0   1  8

# %%
results = {}

our = []
default = []
for _ in range(200):
    x_tr, x_te, y_tr, y_te = train_test_split(standardized_X, Y,  test_size=0.2)

    m = MLPClassifier(hidden_layer_sizes=(15,), max_iter=10000)
    m.fit(x_tr, y_tr)

    model_default = MLPClassifier(max_iter = 10000)
    model_default.fit(x_tr, y_tr)

    default.append(accuracy_score(y_te, model_default.predict(x_te)))
    our.append(accuracy_score(y_te, m.predict(x_te)))

results['our'] = our
results['default'] = default

plt.boxplot(results.values(), labels=results.keys())
plt.xlabel('Hidden layer size')
plt.ylabel('Accuracy')
plt.show()
# Out:
# /var/folders/y0/dl2c3bsn41b0y9ffbsz7z3th0000gn/T/ipykernel_14212/1256105334.py:20: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(results.values(), labels=results.keys())

# %%
results = {}
r = [15, 100]

for i in r:
    norm= []
    over= []
    for _ in range(100):
        x_tr, x_te, y_tr, y_te = train_test_split(standardized_X, Y, test_size=0.2)
        mN = MLPClassifier(hidden_layer_sizes=(i,), max_iter=10000)
        mN.fit(x_tr, y_tr)
        norm.append(accuracy_score(y_te, mN.predict(x_te)))
        
        x_trO, x_teO, y_trO, y_teO = train_test_split(standardized_X_ros, Y_ros, test_size=0.2)
        mO = MLPClassifier(hidden_layer_sizes=(i,), max_iter=10000)
        mO.fit(x_trO, y_trO)
        over.append(accuracy_score(y_teO, mO.predict(x_teO))) 
        
    print(f'[{i}] norm:  mean:{np.mean(norm):.4f} max:{max(norm):.4f} min:{min(norm):.4f}')
    print(f'[{i}] over:  mean:{np.mean(over):.4f} max:{max(over):.4f} min:{min(over):.4f}')
        
    results[f'{i}_normal'] = norm
    results[f'{i}_over'] = over

plt.boxplot(results.values(), labels=results.keys())
plt.xlabel('type')
plt.ylabel('Accuracy')
plt.show()
# Out:
# [15] norm:  mean:0.9733 max:1.0000 min:0.8611
# [15] over:  mean:0.9753 max:1.0000 min:0.9070
# [100] norm:  mean:0.9800 max:1.0000 min:0.9167
# [100] over:  mean:0.9781 max:1.0000 min:0.8837
# /var/folders/y0/dl2c3bsn41b0y9ffbsz7z3th0000gn/T/ipykernel_14212/384925562.py:24: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(results.values(), labels=results.keys())

# %%
#Default model (100 neurons) vs our model (100 neurons, standardized, oversampled)
results = {}

our = []
default = []
for _ in range(200):
    x_trO, x_teO, y_trO, y_teO = train_test_split(standardized_X_ros, Y_ros, test_size=0.2)

    m = MLPClassifier(hidden_layer_sizes=(100,), max_iter=10000)
    m.fit(x_trO, y_trO)
    our.append(accuracy_score(y_teO, m.predict(x_teO))) 

    x_tr, x_te, y_tr, y_te = train_test_split(X,Y,  test_size=0.2)
    
    model_default = MLPClassifier(max_iter = 10000)
    model_default.fit(x_tr, y_tr)
    default.append(accuracy_score(y_te, model_default.predict(x_te)))

print(f'our model is getting an mean of {np.mean(our)}')

results['our'] = our
results['default'] = default

plt.boxplot(results.values(), labels=results.keys())
plt.xlabel('Hidden layer size')
plt.ylabel('Accuracy')
plt.show()

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html

# %%
[10**-p * m for p in range(2, 5) for m in (1, 3)]
# Out:
# [0.01, 0.03, 0.001, 0.003, 0.0001, 0.00030000000000000003]

# %%
r1=list(range(15,100,28))
r2=list(range(57,100,42))
H_param = {'hidden_layer_sizes': [(i,) for i in r1] + [(i,j,) for i in r2 for j in r2],
           'activation': ['tanh', 'relu', 'identity', 'logistic'],
           'learning_rate': ['constant', 'adaptive'],
           'learning_rate_init': [10**-p * m for p in range(2, 5) for m in (1, 3)],
           'alpha': [10**-p for p in range(2, 7)]}
for t in range(3):    
    m = MLPClassifier(max_iter=10000)
    optimal_param = GridSearchCV(m, H_param)
    optimal_param.fit(standardized_X_ros, Y_ros)
    print(f'at {t}: {optimal_param.best_params_}')

# at 0: {'activation': 'relu', 'hidden_layer_sizes': (57, 99), 'learning_rate': 'adaptive', 'learning_rate_init': 0.001}
# at 1: {'activation': 'tanh', 'hidden_layer_sizes': (15,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.01}
# at 2: {'activation': 'tanh', 'hidden_layer_sizes': (15,), 'learning_rate': 'constant', 'learning_rate_init': 0.01}
    
# at 0: {'activation': 'tanh', 'hidden_layer_sizes': (15,), 'learning_rate': 'constant', 'learning_rate_init': 0.1}
# at 1: {'activation': 'relu', 'hidden_layer_sizes': (99, 99), 'learning_rate': 'constant', 'learning_rate_init': 0.001}
# at 2: {'activation': 'relu', 'hidden_layer_sizes': (57, 99), 'learning_rate': 'constant', 'learning_rate_init': 0.001}

# at 0: {'activation': 'tanh', 'hidden_layer_sizes': (99, 57), 'learning_rate': 'constant', 'learning_rate_init': 0.001}
# at 1: {'activation': 'identity', 'hidden_layer_sizes': (71,), 'learning_rate': 'constant', 'learning_rate_init': 0.001}
# at 2: {'activation': 'identity', 'hidden_layer_sizes': (57, 99), 'learning_rate': 'adaptive', 'learning_rate_init': 0.01}

# at 0: {'activation': 'tanh', 'hidden_layer_sizes': (15,), 'learning_rate': 'constant', 'learning_rate_init': 0.01}

# BEST LARGE MODEL:
H_param = {'hidden_layer_sizes': [(i,j,) for i in r2 for j in r2],
           'activation': ['relu', 'identity'],
           'learning_rate': ['constant', 'adaptive'],
           'learning_rate_init': [10**-p for p in list(range(3,6))]}
for t in range(0):    
    m = MLPClassifier(max_iter=10000)
    optimal_param = GridSearchCV(m, H_param)
    optimal_param.fit(standardized_X_ros, Y_ros)
    print(f'LARGE MODEL {t}: {optimal_param.best_params_}')
    

# LARGE MODEL 0: {'activation': 'relu', 'hidden_layer_sizes': (57, 99), 'learning_rate': 'adaptive', 'learning_rate_init': 0.001}
# LARGE MODEL 1: {'activation': 'relu', 'hidden_layer_sizes': (99, 57), 'learning_rate': 'constant', 'learning_rate_init': 0.001}
# LARGE MODEL 2: {'activation': 'relu', 'hidden_layer_sizes': (99, 57), 'learning_rate': 'constant', 'learning_rate_init': 0.001}


# BEST SMALL MODEL:
H_param = {'hidden_layer_sizes': [(i,) for i in r1],
           'learning_rate': ['constant', 'adaptive'],
           'learning_rate_init': [10**-p for p in list(range(1,3))]}
for t in range(0):    
    m = MLPClassifier(max_iter=10000, activation='tanh')
    optimal_param = GridSearchCV(m, H_param)
    optimal_param.fit(standardized_X_ros, Y_ros)
    print(f'SMALL MODEL {t}: {optimal_param.best_params_}')
# SMALL MODEL 0: {'hidden_layer_sizes': (71,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.01}
# SMALL MODEL 1: {'hidden_layer_sizes': (15,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.1}
# SMALL MODEL 2: {'hidden_layer_sizes': (15,), 'learning_rate': 'constant', 'learning_rate_init': 0.1}
# SMALL MODEL 3: {'hidden_layer_sizes': (15,), 'learning_rate': 'constant', 'learning_rate_init': 0.1}
# SMALL MODEL 4: {'hidden_layer_sizes': (71,), 'learning_rate': 'constant', 'learning_rate_init': 0.01}
# SMALL MODEL 5: {'hidden_layer_sizes': (15,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.01}
# SMALL MODEL 6: {'hidden_layer_sizes': (15,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.1}
# SMALL MODEL 7: {'hidden_layer_sizes': (15,), 'learning_rate': 'constant', 'learning_rate_init': 0.01}
# SMALL MODEL 8: {'hidden_layer_sizes': (99,), 'learning_rate': 'constant', 'learning_rate_init': 0.1}
# SMALL MODEL 9: {'hidden_layer_sizes': (43,), 'learning_rate': 'constant', 'learning_rate_init': 0.1}
# SMALL MODEL 10: {'hidden_layer_sizes': (15,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.1}
# SMALL MODEL 11: {'hidden_layer_sizes': (15,), 'learning_rate': 'constant', 'learning_rate_init': 0.01}
# SMALL MODEL 12: {'hidden_layer_sizes': (15,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.01}
# SMALL MODEL 13: {'hidden_layer_sizes': (71,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.01}
# SMALL MODEL 14: {'hidden_layer_sizes': (43,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.01}
# SMALL MODEL 15: {'hidden_layer_sizes': (43,), 'learning_rate': 'constant', 'learning_rate_init': 0.1}
# SMALL MODEL 16: {'hidden_layer_sizes': (99,), 'learning_rate': 'constant', 'learning_rate_init': 0.1}
# SMALL MODEL 17: {'hidden_layer_sizes': (15,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.01}
# SMALL MODEL 18: {'hidden_layer_sizes': (15,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.01}
# SMALL MODEL 19: {'hidden_layer_sizes': (15,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.1}
# SMALL MODEL 20: {'hidden_layer_sizes': (15,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.01}
# SMALL MODEL 21: {'hidden_layer_sizes': (15,), 'learning_rate': 'constant', 'learning_rate_init': 0.1}
# SMALL MODEL 22: {'hidden_layer_sizes': (15,), 'learning_rate': 'constant', 'learning_rate_init': 0.1}
# SMALL MODEL 23: {'hidden_layer_sizes': (15,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.01}
# SMALL MODEL 24: {'hidden_layer_sizes': (71,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.01}
# SMALL MODEL 25: {'hidden_layer_sizes': (15,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.01}
# SMALL MODEL 26: {'hidden_layer_sizes': (15,), 'learning_rate': 'constant', 'learning_rate_init': 0.1}
# SMALL MODEL 27: {'hidden_layer_sizes': (15,), 'learning_rate': 'constant', 'learning_rate_init': 0.01}
# SMALL MODEL 28: {'hidden_layer_sizes': (43,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.01}
# SMALL MODEL 29: {'hidden_layer_sizes': (15,), 'learning_rate': 'adaptive', 'learning_rate_init': 0.01}
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:698: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:698: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:698: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:698: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:698: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# ...

# %%
l_mean = []
s_mean = []
l_std = []
s_std = []
o = 3

for i in range(o):    
    lt = []
    st = []
    for _ in range(50):
        X_rosO, Y_rosO = X, Y
        for j in range(i):
            X_rosO, Y_rosO = ros.fit_resample(X_rosO, Y_rosO) 
        
        x_tr, x_te, y_tr, y_te = train_test_split(preprocessing.scale(X_rosO), Y_rosO, test_size=0.2)
        
        ml = MLPClassifier(max_iter=10000, activation='relu', hidden_layer_sizes=(99, 57), learning_rate='constant', learning_rate_init=0.001)
        ml.fit(x_tr, y_tr)
        lt.append(accuracy_score(y_te, ml.predict(x_te)))
            
        ms = MLPClassifier(max_iter=10000, activation='tanh', hidden_layer_sizes=(15,), learning_rate='adaptive', learning_rate_init=0.01)
        ms.fit(x_tr, y_tr)
        st.append(accuracy_score(y_te, ms.predict(x_te)))
    
    l_mean.append(np.mean(lt))
    s_mean.append(np.mean(st))
    print(f'mean large: {np.mean(lt)} at: {list(range(i))}')
    print(f'mean small: {np.mean(st)}\n\n')
    l_std.append(np.std(lt))
    s_std.append(np.std(st))

# Plot with std bands
x = range(o)
l_mean = np.array(l_mean)
s_mean = np.array(s_mean)
l_std = np.array(l_std)
s_std = np.array(s_std)

plt.plot(x, l_mean, label="large")
plt.fill_between(x, l_mean - l_std, l_mean + l_std, alpha=0.2)

plt.plot(x, s_mean, label="small")
plt.fill_between(x, s_mean - s_std, s_mean + s_std, alpha=0.2)

plt.legend()
plt.show()
# Out:
# mean large: 0.9822222222222223 at: []
# mean small: 0.9794444444444445
#
#
# mean large: 0.9865116279069767 at: [0]
# mean small: 0.9865116279069768
#
#
# mean large: 0.9846511627906976 at: [0, 1]
# mean small: 0.9818604651162791
